# %%
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get(url="https://www.infowars.com/sen-rand-paul-slapping-someone-could-get-you-10-years-in-prison-under-federal-anti-lynching-bill/")
soup = BeautifulSoup(page.content, "html")
nlp = spacy.load("en_core_web_sm")

# %%
# kill all script and style elements
for script in soup(["script", "style"]):
    script.decompose()    # rip it out

# get text
text = soup.get_text()

# break into lines and remove leading and trailing space on each
# lines = (line.strip() for line in text.splitlines())
# # break multi-headlines into a line each
# chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# # drop blank lines
# text = '\n'.join(chunk for chunk in chunks if chunk)

print(text)
# Out:
# Sen. Rand Paul: Slapping Someone Could Get You 10 Years In Prison Under Federal ‘Anti-Lynching’ Bill
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The
# The Alex Jones Radio Show
#
# Listen nowWatch Now
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Radio Show
#
# Watch
# About Alex Jones
# Radio Show Archive
#
#
# News
#
# Featured Stories
# Special Reports
# U.S. News
# World News
# Economy
# Government
# World at War
# Health
# Science & Technology
# Globalism
# Hot News
#
#
# Videos
#
# Alex Jones
# The David Knight Show
# War Room
# Paul Joseph Watson
# Special Reports
# Infowars Archive
# banned.video
#
#
# Store
# Breaking News
# Contact
#
# Media Inquiries
# Affiliates
# Advertise
# Contributors
# Social Media
#
#
#
#
# Newsletter
#
#
#
#
# ...

# %%
import spacy

# %%
token.is

# %%
doc = nlp(text)

# %%
print("\n".join([token.lemma_.lower()
                 for token in doc 
                 if token.is_alpha is True 
                 and token.is_stop is not True 
                 and token.is_digit is not True]))
# Out:
# rand
# paul
# slap
# year
# prison
# federal
# anti
# lynching
# bill
# skip
# content
# alex
# jones
# radio
# listen
# nowwatch
# radio
# watch
# alex
# jones
# radio
# archive
# news
# featured
# stories
# special
# reports
# news
# world
# news
# economy
# government
# world
# war
# health
# science
# technology
# globalism
# hot
# news
# videos
# alex
# jones
# david
# knight
# war
# room
# paul
# joseph
# watson
# special
# reports
# infowars
# archive
# store
# break
# news
# contact
# media
# inquiry
# affiliate
# advertise
# contributor
# social
# media
# newsletter
# subscribe
# ban
# watch
# live
# break
# store
# rand
# paul
# slap
# year
# prison
# federal
# anti
# lynching
# bill
# lynch
# illegal
# bill
# create
# new
# crime
# call
# conspiracy
# lynch
# allow
# fed
# ramp
# mass
# incarceration
# thought
# crime
# chris
# menahan
# information
# liberation
# june
# comments
# image
# credits
# screenshot
# youtube
# democratic
# senators
# kamala
# harris
# cory
# ...

# %%
token.
# Out:
# 'Rand'

# %%
url="https://www.cnn.com/2020/06/07/us/george-floyd-protests-sunday/index.html"

# %%
result = requests.post(url="http://0.0.0.0:8080/predict",
                       json={'url':url})

# %%
result.json()
# Out:
# 1115
